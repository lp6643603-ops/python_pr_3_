# %% [markdown]
# **PROJECT NO.(1) FUNDAMENTAL BOOSTER**

# %%
print("welcome to the interactive personal data collector!")
name=input("enter your name")
age=input("enter your age")
height=float(input("enter your height"))
fav_num=int(input("enter your number"))
age = int(input("enter your age:"))
current_year = 2026
birth_year = current_year - age
print("your birth year is:", birth_year)
print("thank you! here is the information we collected")
# VARIABLE DETAILS
print(type(name))
#data type
print(type(name))
print(type(age))
print(type(height))
print(type(fav_num))
#id number jo hamesha unique rehta hai
print(id(name))
#type casting
height_int=int(height)
height_int
print(type(height))
print(type(height_int))
#summary
print("name:",name)
print("age:",age)
print("height:",height)
print("favourite number:", fav_num)
print("birth year:",birth_year)
print("thank you for using the personal tha data collector .goodbye!")
# Out:
# welcome to the interactive personal data collector!
# enter your nameLaxman
# enter your age18
# enter your height5.9
# enter your number07
# enter your age:18
# your birth year is: 2008
# thank you! here is the information we collected
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# 134357116607568
# <class 'float'>
# <class 'int'>
# name: Laxman
# age: 18
# height: 5.9
# favourite number: 7
# birth year: 2008
# thank you for using the personal tha data collector .goodbye!
